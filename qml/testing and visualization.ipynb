# %%
import main 

circ = main.main()
circ.draw()
# Out:
# [array([3.83984693, 2.71660935, 5.03142025, 2.02997815, 0.25148958,
#        4.24360044, 3.07189475, 2.11768344, 5.41122478, 1.69614621,
#        2.93026644, 2.50957925, 5.91744779, 6.01792945, 5.94230009])]
# [[ 3.83984693+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -3.83984693+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]]
# [[0.        +0.j 2.71660935+0.j 0.        +0.j 0.        +0.j]
#  [2.71660935+0.j 0.        +0.j 0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]]
# [[0.+0.j         0.-5.03142025j 0.+0.j         0.+0.j        ]
#  [0.+5.03142025j 0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]
# ...
