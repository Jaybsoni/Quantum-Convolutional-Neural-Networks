# %%
import main 

circ = main.main()
# print(wf.data)
circ.draw(reverse_bits=True)
# Out:
#                       ┌──────┐┌──────┐┌──────┐ ░                         »
# q_14: ────────────────┤0     ├┤0     ├┤0     ├─░─────────────────────────»
#       ┌──────┐┌──────┐│      ││      ││  U_1 │ ░                         »
# q_13: ┤0     ├┤0     ├┤  U_1 ├┤      ├┤1     ├─░─────────────────────────»
#       │  U_1 ││      ││      ││  U_1 │├──────┤ ░                 ┌──────┐»
# q_12: ┤1     ├┤  U_1 ├┤1     ├┤      ├┤0     ├─░─────────────────┤0     ├»
#       └──────┘│      │└──────┘│      ││  U_1 │ ░ ┌──────┐┌──────┐│      │»
# q_11: ────────┤1     ├────────┤1     ├┤1     ├─░─┤0     ├┤0     ├┤  U_1 ├»
#               └──────┘        └──────┘└──────┘ ░ │  U_1 ││      ││      │»
# q_10: ─────────────────────────────────────────░─┤1     ├┤  U_1 ├┤1     ├»
#                                                ░ └──────┘│      │└──────┘»
#  q_9: ─────────────────────────────────────────░─────────┤1     ├────────»
# ...

# %%
from qiskit import *
circuit = qiskit.QuantumCircuit(2)
# circuit.x(0)
circuit.cnot(0,1)
circuit = circuit.reverse_bits()  # Qiskit uses a different notation for qubit in their unitaries
circuit.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └─┬─┘
# q_1: ──■──

# %%
#circuit already defined
backend = Aer.get_backend('unitary_simulator')
job = execute(circuit, backend)
result = job.result()
print(result.get_unitary(circuit, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]]

# %%
from qiskit import quantum_info as qi
# new_backend = Aer.get_backend('')
wave_func = qi.Statevector([0, 1, 0, 0])
print(wave_func.data)
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j]

# %%
wave_func = wave_func.evolve(circuit)
print(wave_func.data)
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j]

# %%
new_circ = qiskit.QuantumCircuit(2)
new_circ.h(0)
new_circ.cx(0,1) 
new_circ = new_circ.reverse_bits()
new_circ.draw(reverse_bits=True)
# Out:
#      ┌───┐
# q_1: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_0: ─────┤ X ├
#           └───┘

# %%
backend = Aer.get_backend('unitary_simulator')
job = execute(new_circ, backend)
result = job.result()
print(result.get_unitary(new_circ, decimals=3))
# Out:
# [[ 0.70710678+0.00000000e+00j  0.        +0.00000000e+00j
#    0.70710678-8.65956056e-17j  0.        +0.00000000e+00j]
#  [ 0.        +0.00000000e+00j  0.70710678+0.00000000e+00j
#    0.        +0.00000000e+00j  0.70710678-8.65956056e-17j]
#  [ 0.        +0.00000000e+00j  0.70710678+0.00000000e+00j
#    0.        +0.00000000e+00j -0.70710678+8.65956056e-17j]
#  [ 0.70710678+0.00000000e+00j  0.        +0.00000000e+00j
#   -0.70710678+8.65956056e-17j  0.        +0.00000000e+00j]]

# %%
import numpy as np 
q1 = (1 / np.sqrt(2) ) * np.array([1.0 , -1.0])
q2 = np.array([1.0, 0])
q = np.kron(q1, q2)
new_wave_func = qi.Statevector(q)
print(new_wave_func.data)
# Out:
# [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]

# %%
new_wave_func = new_wave_func.evolve(new_circ)
print(new_wave_func.data)
# Out:
# [-2.23711432e-17+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j
#   1.00000000e+00+0.j]
