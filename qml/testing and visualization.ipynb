# %%
import main 

circ = main.main()
# print(wf.data)
circ.draw()
# Out:
# start_index: 0, working_index: 0
# start_index: 0, working_index: 3
# start_index: 0, working_index: 6
# start_index: 0, working_index: 9
# start_index: 0, working_index: 12
# start_index: 1, working_index: 1
# start_index: 1, working_index: 4
# start_index: 1, working_index: 7
# start_index: 1, working_index: 10
# start_index: 2, working_index: 2
# start_index: 2, working_index: 5
# start_index: 2, working_index: 8
# start_index: 2, working_index: 11
#                                                ░                         »
#  q_0: ─────────────────────────────────────────░─────────────────────────»
#                                                ░                         »
#  q_1: ─────────────────────────────────────────░─────────────────────────»
#                       ┌──────┐┌──────┐┌──────┐ ░                         »
#  q_2: ────────────────┤0     ├┤0     ├┤0     ├─░─────────────────────────»
#       ┌──────┐┌──────┐│      ││      ││  U_1 │ ░                         »
# ...
